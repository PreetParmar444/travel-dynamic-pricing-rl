# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
from src.env.pricing_env import DynamicPricingEnv

# %%
env = DynamicPricingEnv()

state, info = env.reset()

print(state)
# Out:
# [100  30]

# %%
terminated = False

while not terminated:

    action = env.action_space.sample()

    state, reward, terminated, truncated, info = env.step(action)

    print(
        state,
        reward,
        info
    )
# Out:
# [100  29] 0 {'price': 100, 'sale': np.False_, 'revenue': 0}
# [100  28] 0 {'price': 160, 'sale': np.False_, 'revenue': 0}
# [100  27] 0 {'price': 120, 'sale': np.False_, 'revenue': 0}
# [100  26] 0 {'price': 100, 'sale': np.False_, 'revenue': 0}
# [99 25] 120 {'price': 120, 'sale': np.True_, 'revenue': 120}
# [99 24] 0 {'price': 160, 'sale': np.False_, 'revenue': 120}
# [99 23] 0 {'price': 120, 'sale': np.False_, 'revenue': 120}
# [99 22] 0 {'price': 100, 'sale': np.False_, 'revenue': 120}
# [99 21] 0 {'price': 140, 'sale': np.False_, 'revenue': 120}
# [99 20] 0 {'price': 160, 'sale': np.False_, 'revenue': 120}
# [99 19] 0 {'price': 80, 'sale': np.False_, 'revenue': 120}
# [98 18] 160 {'price': 160, 'sale': np.True_, 'revenue': 280}
# [98 17] 0 {'price': 140, 'sale': np.False_, 'revenue': 280}
# [98 16] 0 {'price': 160, 'sale': np.False_, 'revenue': 280}
# [97 15] 80 {'price': 80, 'sale': np.True_, 'revenue': 360}
# [96 14] 140 {'price': 140, 'sale': np.True_, 'revenue': 500}
# [95 13] 100 {'price': 100, 'sale': np.True_, 'revenue': 600}
# [94 12] 140 {'price': 140, 'sale': np.True_, 'revenue': 740}
# [94 11] 0 {'price': 140, 'sale': np.False_, 'revenue': 740}
# [94 10] 0 {'price': 140, 'sale': np.False_, 'revenue': 740}
# [93  9] 160 {'price': 160, 'sale': np.True_, 'revenue': 900}
# [93  8] 0 {'price': 100, 'sale': np.False_, 'revenue': 900}
# [92  7] 120 {'price': 120, 'sale': np.True_, 'revenue': 1020}
# [92  6] 0 {'price': 100, 'sale': np.False_, 'revenue': 1020}
# [91  5] 140 {'price': 140, 'sale': np.True_, 'revenue': 1160}
# [90  4] 120 {'price': 120, 'sale': np.True_, 'revenue': 1280}
# [90  3] 0 {'price': 120, 'sale': np.False_, 'revenue': 1280}
# [90  2] 0 {'price': 160, 'sale': np.False_, 'revenue': 1280}
# [90  1] 0 {'price': 100, 'sale': np.False_, 'revenue': 1280}
# [89  0] 120 {'price': 120, 'sale': np.True_, 'revenue': 1400}
