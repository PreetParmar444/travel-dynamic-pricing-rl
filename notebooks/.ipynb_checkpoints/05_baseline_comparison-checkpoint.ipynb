# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

import matplotlib.pyplot as plt

from src.env.pricing_env import DynamicPricingEnv
from src.agents.baseline import (
    FixedPriceAgent,
    TimeBasedDiscountAgent,
)

from src.utils.evaluate import evaluate_agent

# %%
env = DynamicPricingEnv()

fixed_agent = FixedPriceAgent(price_index=2)

fixed_results = evaluate_agent(
    env,
    fixed_agent,
    episodes=200
)

# %%
discount_agent = TimeBasedDiscountAgent()

discount_results = evaluate_agent(
    env,
    discount_agent,
    episodes=200
)

# %%
print("Fixed Price")

print(fixed_results)

print()

print("Time-Based Discount")

print(discount_results)
# Out:
# Fixed Price
# {'average_revenue': np.float64(1443.0), 'max_revenue': np.int64(2280), 'min_revenue': np.int64(480), 'std_revenue': np.float64(332.64846309580327), 'revenues': [1320, 1800, 1920, 1200, 1320, 1200, 1800, 1440, 960, 1200, 1080, 1680, 1440, 1440, 1200, 1320, 1200, 1440, 1800, 1200, 1440, 1440, 1440, 1200, 1200, 1200, 840, 2160, 1680, 840, 1920, 1320, 960, 2160, 1320, 1800, 1920, 1080, 1560, 1200, 1320, 1560, 1200, 1080, 1560, 1800, 1920, 1200, 1080, 1440, 1920, 1920, 1320, 720, 1680, 1440, 1320, 1440, 1800, 2280, 1320, 1080, 960, 1680, 1560, 1320, 1320, 1560, 1200, 1800, 1440, 1680, 1560, 1680, 720, 1080, 1440, 1440, 2040, 1320, 1440, 1680, 960, 1800, 1320, 1680, 1080, 1680, 1320, 1320, 960, 1920, 1800, 1680, 1440, 1920, 1200, 1440, 1800, 1440, 1200, 1440, 840, 1560, 1200, 1080, 1080, 1080, 2280, 1560, 1320, 1680, 1440, 840, 1440, 1200, 1320, 1200, 1800, 1320, 1560, 1440, 1080, 840, 1440, 1440, 1680, 1080, 1440, 1440, 1320, 1920, 1680, 840, 1800, 1440, 1560, 1440, 1800, 1800, 1800, 2040, 1440, 1440, 1800, 2160, 1680, 1200, 1320, 1560, 1440, 840, 1440, 1440, 1080, 960, 1440, 1080, 1560, 1680, 1320, 1320, 1080, 1200, 2040, 1560, 1320, 1680, 1560, 1320, 1560, 1200, 1440, 1320, 1440, 1440, 480, 1680, 960, 1920, 1560, 960, 1800, 2280, 1680, 1920, 1440, 1440, 1440, 960, 1320, 1800, 1080, 2040, 2160, 1560, 1320, 1200, 1200, 1560]}
#
# Time-Based Discount
# {'average_revenue': np.float64(1482.6), 'max_revenue': np.int64(2200), 'min_revenue': np.int64(620), 'std_revenue': np.float64(285.25294038800024), 'revenues': [1400, 1360, 1560, 1040, 1380, 1620, 1700, 1360, 1920, 1340, 2200, 1220, 1220, 1840, 840, 1320, 1580, 1360, 1620, 1680, 1520, 1280, 1260, 1620, 1580, 1280, 1800, 1360, 1380, 1200, 2120, 1580, 1640, 1580, 1780, 1240, 1640, 1860, 1480, 1320, 1280, 1460, 1480, 1360, 1640, 1460, 1380, 1600, 1420, 2000, 1820, 1520, 1720, 1420, 1680, 1520, 1200, 1560, 1120, 1520, 1500, 1180, 2060, 2060, 2000, 940, 1780, 1860, 1400, 1500, 1360, 1500, 1640, 1660, 1800, 1180, 1340, 1460, 1600, 1540, 1300, 820, 1360, 1300, 1080, 1060, 1120, 1600, 1400, 1740, 1360, 1860, 1680, 1320, 1800, 1380, 1300, 1440, 1200, 1220, 1960, 2180, 1300, 1280, 1180, 1980, 1600, 1480, 1260, 1820, 1260, 1520, 1520, 1540, 1320, 1400, 1280, 1240, 1360, 1720, 1720, 2100, 1040, 1580, 1700, 1880, 1400, 1100, 1940, 1460, 1220, 1220, 1140, 1440, 1440, 1360, 1720, 1540, 2120, 1740, 1780, 1920, 1200, 1560, 1400, 1340, 1580, 1320, 1620, 1540, 1620, 1240, 1480, 1280, 1600, 1400, 1120, 1360, 1840, 1540, 620, 1540, 1420, 1200, 1320, 1420, 1400, 1700, 1640, 1200, 1420, 1300, 1720, 2200, 1760, 940, 1140, 2100, 1480, 900, 1720, 1320, 1500, 1360, 1800, 1380, 1160, 1160, 900, 1440, 2060, 1680, 1800, 1040, 1480, 1340, 1160, 1240, 1640, 1180]}

# %%
strategies = [
    "Fixed",
    "Discount"
]

average_revenue = [
    fixed_results["average_revenue"],
    discount_results["average_revenue"]
]

plt.figure(figsize=(6,5))

plt.bar(
    strategies,
    average_revenue
)

plt.title("Baseline Strategy Comparison")

plt.ylabel("Average Revenue")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(
    fixed_results["revenues"],
    alpha=0.6,
    label="Fixed"
)

plt.hist(
    discount_results["revenues"],
    alpha=0.6,
    label="Discount"
)

plt.legend()

plt.title("Revenue Distribution")

plt.xlabel("Revenue")

plt.show()
